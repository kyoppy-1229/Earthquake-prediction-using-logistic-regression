# %%
pip instfolium

# %%
pip install scikit-learn

# %%
pip install pandas

# %%
pip install numpy

# %%
pip install geocoder

# %%
pip install tensorflow

# %%
import folium
import pandas as pd
import csv
import numpy as np
from google.colab import drive

drive.mount('/content/drive')

df = pd.read_csv('/content/drive/My Drive/all/地震データ.csv', usecols = ['緯度3','経度3','最大震度2'], encoding='utf-8')

df = df.dropna()

folium_map = folium.Map(location=[35.72349, 139.749553], zoom_start=5)

for i, row in df.iterrows():
a
    count = row['最大震度2']
    if count <= 2:
            folium.Marker(
                location=[row['緯度3'], row['経度3']],
                icon=folium.Icon(color='red')
            ).add_to(folium_map)
    else:
        folium.Marker(
            location=[row['緯度3'], row['経度3']],
            icon=folium.Icon(color='blue')
        ).add_to(folium_map)

# 地図表示
folium_map

# %%
from sklearn.linear_model import LogisticRegression as lr
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from google.colab import drive
import pickle
import folium

drive.mount('/content/drive')

data = pd.read_csv('/content/drive/My Drive/all/all2.csv')

X_data = data[['緯度3','経度3']]
Y_data = data['最大震度2']

X_train,X_test,y_train,y_test = train_test_split(X_data,Y_data,test_size = 0.1)
clf = lr(max_iter=1000)
clf.fit(X_train,y_train)

result = clf.score(X_test, y_test)

print(result)

df = pd.DataFrame({"経度3":[139.7266667], "緯度3":[35.98666667]})

clf.predict(df)

# %%
location = input()
ret = geocoder.osm(location, timeout=5.0)

dataframe = (ret.latlng)

loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)

result = str(result * 100)

folium_map = folium.Map(location=ret.latlng, zoom_start=15)

folium.Marker(location = ret.latlng, popup='地震が起こる可能性' + result + '%').add_to(folium_map)

folium_map
